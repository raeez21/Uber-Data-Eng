# %%
import pandas as pd

# %%
path_to_data = "./Data/uber_data.csv"
df = pd.read_csv(path_to_data)

# %%
df.head(5)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2016-03-01 00:00:00   2016-03-01 00:07:55                1
# 1         1  2016-03-01 00:00:00   2016-03-01 00:11:06                1
# 2         2  2016-03-01 00:00:00   2016-03-01 00:31:06                2
# 3         2  2016-03-01 00:00:00   2016-03-01 00:00:00                3
# 4         2  2016-03-01 00:00:00   2016-03-01 00:00:00                5
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           2.50        -73.976746        40.765152           1
# 1           2.90        -73.983482        40.767925           1
# 2          19.98        -73.782021        40.644810           1
# 3          10.78        -73.863419        40.769814           1
# 4          30.43        -73.971741        40.792183           3
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
df.shape
# Out:
# (100000, 19)

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a74c58233b9e> in <module>
# ----> 1 df.info()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in info(self, verbose, buf, max_cols, memory_usage, null_counts)
#    2570                 if "object" in counts or self.index._is_memory_usage_qualified():
#    2571                     size_qualifier = "+"
# -> 2572             mem_usage = self.memory_usage(index=True, deep=deep).sum()
#    2573             lines.append(
#    2574                 "memory usage: {mem}\n".format(
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in memory_usage(self, index, deep)
#    2668         )
#    2669         if index:
# -> 2670             result = Series(self.index.memory_usage(deep=deep), index=["Index"]).append(
#    2671                 result
#    2672             )
#
# ...

# %%
#Convert date columns into datetime format
df["tpep_pickup_datetime"] = pd.to_datetime(df["tpep_pickup_datetime"])
df["tpep_dropoff_datetime"] = pd.to_datetime(df["tpep_dropoff_datetime"])

# %%
#Dropping the duplicates and assingning a primary key
df = df.drop_duplicates().reset_index(drop=True)
df['trip_id'] = df.index

# %%
df.head(5)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1           2016-03-01   2016-03-01 00:07:55                1
# 1         1           2016-03-01   2016-03-01 00:11:06                1
# 2         2           2016-03-01   2016-03-01 00:31:06                2
# 3         2           2016-03-01   2016-03-01 00:00:00                3
# 4         2           2016-03-01   2016-03-01 00:00:00                5
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           2.50        -73.976746        40.765152           1
# 1           2.90        -73.983482        40.767925           1
# 2          19.98        -73.782021        40.644810           1
# 3          10.78        -73.863419        40.769814           1
# 4          30.43        -73.971741        40.792183           3
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
df.shape
# Out:
# (100000, 20)

# %%
datetime_dim = df[["tpep_pickup_datetime", "tpep_dropoff_datetime"]].drop_duplicates().reset_index(drop=True)
#setting pick attributes
datetime_dim["pick_hour"] = datetime_dim["tpep_pickup_datetime"].dt.hour
datetime_dim["pick_day"] = datetime_dim["tpep_pickup_datetime"].dt.day
datetime_dim["pick_month"] = datetime_dim["tpep_pickup_datetime"].dt.month
datetime_dim["pick_year"] = datetime_dim["tpep_pickup_datetime"].dt.year
datetime_dim["pick_weekday"] = datetime_dim["tpep_pickup_datetime"].dt.weekday

#setting drop attributes
datetime_dim["drop_hour"] = datetime_dim["tpep_dropoff_datetime"].dt.hour
datetime_dim["drop_day"] = datetime_dim["tpep_dropoff_datetime"].dt.day
datetime_dim["drop_month"] = datetime_dim["tpep_dropoff_datetime"].dt.month
datetime_dim["drop_year"] = datetime_dim["tpep_dropoff_datetime"].dt.year
datetime_dim["drop_weekday"] = datetime_dim["tpep_dropoff_datetime"].dt.weekday

#setting index as datetime_id (PK)
datetime_dim['datetime_id'] = datetime_dim.index

#Reorder the columns 
datetime_dim = datetime_dim[['datetime_id', 'tpep_pickup_datetime', 'pick_hour', 'pick_day', 'pick_month', 'pick_year', 'pick_weekday',
                             'tpep_dropoff_datetime', 'drop_hour', 'drop_day', 'drop_month', 'drop_year', 'drop_weekday']]

# %%
datetime_dim
# Out:
#        datetime_id tpep_pickup_datetime  pick_hour  pick_day  pick_month  \
# 0                0  2016-03-01 00:00:00          0         1           3
# 1                1  2016-03-01 00:00:00          0         1           3
# 2                2  2016-03-01 00:00:00          0         1           3
# 3                3  2016-03-01 00:00:00          0         1           3
# 4                4  2016-03-01 00:00:01          0         1           3
# ...            ...                  ...        ...       ...         ...
# 99848        99848  2016-03-01 06:17:10          6         1           3
# 99849        99849  2016-03-01 06:17:10          6         1           3
# 99850        99850  2016-03-01 06:17:10          6         1           3
# 99851        99851  2016-03-01 06:17:10          6         1           3
# 99852        99852  2016-03-01 06:17:11          6         1           3
#
#        pick_year  pick_weekday tpep_dropoff_datetime  drop_hour  drop_day  \
# ...

# %%
passenger_count_dim = df[["passenger_count"]].drop_duplicates().sort_values('passenger_count')
passenger_count_dim.reset_index(drop=True,inplace=True)
passenger_count_dim["passenger_count_id"] = passenger_count_dim.index
passenger_count_dim = passenger_count_dim[["passenger_count_id", "passenger_count"]]

trip_distance_dim = df[["trip_distance"]].drop_duplicates().reset_index(drop=True)
trip_distance_dim["trip_distance_id"] = trip_distance_dim.index
trip_distance_dim = trip_distance_dim[["trip_distance_id","trip_distance"]]

# %%
passenger_count_dim
# Out:
#    passenger_count_id  passenger_count
# 0                   0                0
# 1                   1                1
# 2                   2                2
# 3                   3                3
# 4                   4                4
# 5                   5                5
# 6                   6                6

# %%
trip_distance_dim
# Out:
#       trip_distance_id  trip_distance
# 0                    0           2.50
# 1                    1           2.90
# 2                    2          19.98
# 3                    3          10.78
# 4                    4          30.43
# ...                ...            ...
# 2298              2298          23.38
# 2299              2299          15.91
# 2300              2300          21.11
# 2301              2301          20.63
# 2302              2302         184.40
#
# [2303 rows x 2 columns]

# %%
rate_code_type = {
    1:"Standard rate",
    2:"JFK",
    3:"Newark",
    4:"Nassau or Westchester",
    5:"Negotiated fare",
    6:"Group ride"
}

rate_code_dim = df[["RatecodeID"]].drop_duplicates().sort_values('RatecodeID')
rate_code_dim.reset_index(inplace=True, drop=True)
rate_code_dim["rate_code_id"] = rate_code_dim.index
rate_code_dim["rate_code_name"] = rate_code_dim["RatecodeID"].map(rate_code_type)
rate_code_dim = rate_code_dim[["rate_code_id","RatecodeID", "rate_code_name"]]

# %%
rate_code_dim
# Out:
#    rate_code_id  RatecodeID         rate_code_name
# 0             0           1          Standard rate
# 1             1           2                    JFK
# 2             2           3                 Newark
# 3             3           4  Nassau or Westchester
# 4             4           5        Negotiated fare
# 5             5           6             Group ride

# %%
payment_type_name = {
    1:"Credit card",
    2:"Cash",
    3:"No charge",
    4:"Dispute",
    5:"Unknown",
    6:"Voided trip"
}
payment_type_dim = df[["payment_type"]].drop_duplicates().sort_values('payment_type')
payment_type_dim.reset_index(inplace=True, drop=True)
payment_type_dim["payment_type_id"] = payment_type_dim.index
payment_type_dim["payment_type_name"] = payment_type_dim["payment_type"].map(payment_type_name)
payment_type_dim = payment_type_dim[["payment_type_id","payment_type", "payment_type_name"]]

# %%
payment_type_dim
# Out:
#    payment_type_id  payment_type payment_type_name
# 0                0             1       Credit card
# 1                1             2              Cash
# 2                2             3         No charge
# 3                3             4           Dispute

# %%
pickup_location_dim = df[["pickup_longitude", "pickup_latitude"]].drop_duplicates().reset_index(drop=True)
pickup_location_dim["pickup_location_id"] = pickup_location_dim.index
pickup_location_dim = pickup_location_dim[["pickup_location_id", "pickup_latitude", "pickup_longitude"]]


dropoff_location_dim = df[["dropoff_longitude", "dropoff_latitude"]].drop_duplicates().reset_index(drop=True)
dropoff_location_dim["dropoff_location_id"] = dropoff_location_dim.index
dropoff_location_dim = dropoff_location_dim[["dropoff_location_id", "dropoff_latitude", "dropoff_longitude"]]

# %%
fact_table = df.merge(passenger_count_dim, on = 'passenger_count') \
               .merge(trip_distance_dim, on='trip_distance') \
               .merge(rate_code_dim, on = 'RatecodeID') \
               .merge(payment_type_dim, on = 'payment_type') \
               .merge(pickup_location_dim, on = ['pickup_longitude', 'pickup_latitude']) \
               .merge(dropoff_location_dim, on=['dropoff_longitude', 'dropoff_latitude'])\
               .merge(datetime_dim, on=['tpep_pickup_datetime','tpep_dropoff_datetime']) \
                [['trip_id','VendorID', 'datetime_id', 'passenger_count_id', 'trip_distance_id', 'rate_code_id',\
                  'store_and_fwd_flag','pickup_location_id','dropoff_location_id', 'payment_type_id','fare_amount',\
                  'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount']]

# %%
fact_table#.sort_values('trip_id')
# Out:
#        trip_id  VendorID  datetime_id  passenger_count_id  trip_distance_id  \
# 0            0         1            0                   1                 0
# 1         1496         2         1491                   1                 0
# 2         2840         2         2834                   1                 0
# 3         3495         2         3488                   1                 0
# 4         3930         2         3923                   1                 0
# ...        ...       ...          ...                 ...               ...
# 99995    70907         1        70806                   1              1829
# 99996    82093         1        81974                   2              2084
# 99997    66038         1        65943                   1               257
# 99998    81770         1        81651                   1               257
# 99999    88859         1        88727                   1              1894
#
# ...

# %%
#CREATE ANALYTICAL LAYER FOR BUILDING DASHBOARDS FROM THE DIMENSION MODEL

# select f.VendorID,
# d.tpep_pickup_datetime,d.tpep_dropoff_datetime,
# p.passenger_count,
# t.trip_distance,
# r.rate_code_name,
# pick.pickup_latitude, pick.pickup_longitude,
# drop.dropoff_latitude, drop.dropoff_longitude,
# pay.payment_type_name,
# f.fare_amount,
# f.extra,
# f.mta_tax,
# f.tip_amount,
# f.tolls_amount,
# f.improvement_surcharge,
# f.total_amount
# from uber-data-analytics-418217.uber_de_dim_model.fact_table f
# join uber-data-analytics-418217.uber_de_dim_model.datetime_dim d on f.datetime_id = d.datetime_id
# join uber-data-analytics-418217.uber_de_dim_model.passenger_count_dim p on f.passenger_count_id = p.passenger_count_id
# join uber-data-analytics-418217.uber_de_dim_model.trip_distance_dim t on f.trip_distance_id = t.trip_distance_id
# join uber-data-analytics-418217.uber_de_dim_model.rate_code_dim r on f.rate_code_id = r.rate_code_id
# join uber-data-analytics-418217.uber_de_dim_model.pickup_location_dim pick on pick.pickup_location_id = f.pickup_location_id
# join uber-data-analytics-418217.uber_de_dim_model.dropoff_location_dim drop on drop.dropoff_location_id = f.dropoff_location_id
# join uber-data-analytics-418217.uber_de_dim_model.payment_type_dim pay on pay.payment_type_id = f.payment_type_id
